# %%
### EDA with 1-day interval data

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
# %cd
# Out:
# C:\Users\DELL

# %%
# %cd C:\\Users\DELL\Downloads
# Out:
# C:\Users\DELL\Downloads

# %%
# %pwd
# Out:
# 'C:\\Users\\DELL\\Downloads'

# %%
df=pd.read_csv('MSFT.csv',sep=",")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     13-03-1986    0.088542    0.101563    0.088542    0.097222    0.061751
# 1     14-03-1986    0.097222    0.102431    0.097222    0.100694    0.063956
# 2     17-03-1986    0.100694    0.103299    0.100694    0.102431    0.065059
# 3     18-03-1986    0.102431    0.103299    0.098958    0.099826    0.063405
# 4     19-03-1986    0.099826    0.100694    0.097222    0.098090    0.062302
# ...          ...         ...         ...         ...         ...         ...
# 8852  27-04-2021  261.579987  263.190002  260.119995  261.970001  261.970001
# 8853  28-04-2021  256.079987  256.540008  252.949997  254.559998  254.559998
# 8854  29-04-2021  255.460007  256.100006  249.000000  252.509995  252.509995
# 8855  30-04-2021  249.740005  253.080002  249.600006  252.179993  252.179993
# 8856  03-05-2021  253.399994  254.350006  251.119995  251.860001  251.860001
#
#           Volume
# 0     1031788800
# ...

# %%
df.head(5)
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  13-03-1986  0.088542  0.101563  0.088542  0.097222   0.061751  1031788800
# 1  14-03-1986  0.097222  0.102431  0.097222  0.100694   0.063956   308160000
# 2  17-03-1986  0.100694  0.103299  0.100694  0.102431   0.065059   133171200
# 3  18-03-1986  0.102431  0.103299  0.098958  0.099826   0.063405    67766400
# 4  19-03-1986  0.099826  0.100694  0.097222  0.098090   0.062302    47894400

# %%
df.tail(5)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 8852  27-04-2021  261.579987  263.190002  260.119995  261.970001  261.970001
# 8853  28-04-2021  256.079987  256.540008  252.949997  254.559998  254.559998
# 8854  29-04-2021  255.460007  256.100006  249.000000  252.509995  252.509995
# 8855  30-04-2021  249.740005  253.080002  249.600006  252.179993  252.179993
# 8856  03-05-2021  253.399994  254.350006  251.119995  251.860001  251.860001
#
#         Volume
# 8852  31014200
# 8853  46903100
# 8854  40589000
# 8855  30929200
# 8856  19598900

# %%
df.isnull().isnull()
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# ...     ...    ...    ...    ...    ...        ...     ...
# 8852  False  False  False  False  False      False   False
# 8853  False  False  False  False  False      False   False
# 8854  False  False  False  False  False      False   False
# 8855  False  False  False  False  False      False   False
# 8856  False  False  False  False  False      False   False
#
# [8857 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.shape
# Out:
# (8857, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8857 entries, 0 to 8856
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8857 non-null   object
#  1   Open       8857 non-null   float64
#  2   High       8857 non-null   float64
#  3   Low        8857 non-null   float64
#  4   Close      8857 non-null   float64
#  5   Adj Close  8857 non-null   float64
#  6   Volume     8857 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 484.5+ KB

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  13-03-1986  0.088542  0.101563  0.088542  0.097222   0.061751  1031788800
# 1  14-03-1986  0.097222  0.102431  0.097222  0.100694   0.063956   308160000
# 2  17-03-1986  0.100694  0.103299  0.100694  0.102431   0.065059   133171200
# 3  18-03-1986  0.102431  0.103299  0.098958  0.099826   0.063405    67766400
# 4  19-03-1986  0.099826  0.100694  0.097222  0.098090   0.062302    47894400

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 8852  27-04-2021  261.579987  263.190002  260.119995  261.970001  261.970001
# 8853  28-04-2021  256.079987  256.540008  252.949997  254.559998  254.559998
# 8854  29-04-2021  255.460007  256.100006  249.000000  252.509995  252.509995
# 8855  30-04-2021  249.740005  253.080002  249.600006  252.179993  252.179993
# 8856  03-05-2021  253.399994  254.350006  251.119995  251.860001  251.860001
#
#         Volume
# 8852  31014200
# 8853  46903100
# 8854  40589000
# 8855  30929200
# 8856  19598900

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.count()
# Out:
# Date         8857
# Open         8857
# High         8857
# Low          8857
# Close        8857
# Adj Close    8857
# Volume       8857
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  8857.000000  8857.000000  8857.000000  8857.000000  8857.000000
# mean     34.831233    35.209355    34.449657    34.840895    29.886536
# std      44.060163    44.513443    43.597704    44.080986    44.195101
# min       0.088542     0.092014     0.088542     0.090278     0.057340
# 25%       3.843750     3.875000     3.812500     3.851563     2.446323
# 50%      26.590000    26.879999    26.290001    26.590000    18.686628
# 75%      36.730000    37.000000    36.110001    36.660000    27.218300
# max     261.660004   263.190002   260.170013   261.970001   261.970001
#
#              Volume
# count  8.857000e+03
# mean   5.953411e+07
# std    3.858121e+07
# min    2.304000e+06
# 25%    3.559720e+07
# 50%    5.269680e+07
# 75%    7.339520e+07
# max    1.031789e+09

# %%
## Detecting Outliers
sns.boxplot(x=df['Open'])

# %%
sns.boxplot(x=df['Close'])

# %%
sns.boxplot(x=df['Volume'])

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# Open         3.288625e+01
# High         3.312500e+01
# Low          3.229750e+01
# Close        3.280844e+01
# Adj Close    2.477198e+01
# Volume       3.779800e+07
# dtype: float64

# %%
df = df[~((df < (Q1-1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   """Entry point for launching an IPython kernel.
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   """Entry point for launching an IPython kernel.
# (7497, 7)

# %%
### Histograms
df.Open.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of Volume by Open Prices")
plt.ylabel('Number of Volume')
plt.xlabel('Open');

# %%
### Heat Maps
# Finding the relations between the variables.
plt.figure(figsize=(10,10))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999858  0.999854  0.999709   0.974874 -0.213636
# High       0.999858  1.000000  0.999792  0.999853   0.973935 -0.209104
# Low        0.999854  0.999792  1.000000  0.999857   0.976176 -0.217673
# Close      0.999709  0.999853  0.999857  1.000000   0.975269 -0.213486
# Adj Close  0.974874  0.973935  0.976176  0.975269   1.000000 -0.282366
# Volume    -0.213636 -0.209104 -0.217673 -0.213486  -0.282366  1.000000

# %%
# Plotting a scatter plot
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Close'], df['Open'])
ax.set_xlabel('Close')
ax.set_ylabel('Open')
plt.show()

# %%
#plot the scatter plot of Open and Volume variable in data
plt.scatter(df.Open,df.Volume)
plt.show()

#plot the scatter plot of balance and age variable in data
df.plot.scatter(x="Close",y="Volume")
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
g = sns.pairplot(df, diag_kind="kde")
g.map_lower(sns.kdeplot, levels=4, color=".2")

# %%
df.Open.describe()
# Out:
# count    7497.000000
# mean       21.972800
# std        16.545714
# min         0.090278
# 25%         2.902344
# 50%        25.709999
# 75%        30.570000
# max        68.889999
# Name: Open, dtype: float64

# %%
### Correlation Matrix 
# Creating a matrix using Open, High, Low as rows and columns
df[['Open','Low','High']].corr()

#plot the correlation matrix of Open, High and Low in data dataframe.
sns.heatmap(df[['Open','Low','High']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
### Pivot table with Three Columns and then Heatmap.
result = pd.pivot_table(data=df, index='Date', columns='Open',values='Close')
print(result)

#create heat map of education vs marital vs response_rate
sns.heatmap(result, annot=True, cmap = 'RdYlGn', center=0.117)
plt.show()
# Out:
# Open        0.090278   0.092014   0.092882   0.094618   0.095486   0.095920   \
# Date
# 01-02-1988        NaN        NaN        NaN        NaN        NaN        NaN
# 01-02-1990        NaN        NaN        NaN        NaN        NaN        NaN
# 01-02-1991        NaN        NaN        NaN        NaN        NaN        NaN
# 01-02-1993        NaN        NaN        NaN        NaN        NaN        NaN
# 01-02-1994        NaN        NaN        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 31-12-2010        NaN        NaN        NaN        NaN        NaN        NaN
# 31-12-2012        NaN        NaN        NaN        NaN        NaN        NaN
# 31-12-2013        NaN        NaN        NaN        NaN        NaN        NaN
# 31-12-2014        NaN        NaN        NaN        NaN        NaN        NaN
# 31-12-2015        NaN        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
corr=df.corr(method='spearman')
plt.figure(figsize=(15,15))
sns.heatmap(corr,vmax=.8,linewidth=0.01,square=True,annot=True,cmap='RdBu',linecolor='black')

# %%
sns.boxplot(df.Open, df.Close)
plt.show()

# %%
df.groupby('Volume')['Open'].mean()
# Out:
# Volume
# 2304000       0.113715
# 2332800       0.100694
# 2419200       0.102431
# 2505600       0.103299
# 2822400       0.098090
#                ...
# 129236800    11.890625
# 129550600    26.020000
# 129640900    22.139999
# 129751900    28.340000
# 129804800     5.687500
# Name: Open, Length: 7328, dtype: float64

# %%
df.groupby('Volume')['Open'].median()
# Out:
# Volume
# 2304000       0.113715
# 2332800       0.100694
# 2419200       0.102431
# 2505600       0.103299
# 2822400       0.098090
#                ...
# 129236800    11.890625
# 129550600    26.020000
# 129640900    22.139999
# 129751900    28.340000
# 129804800     5.687500
# Name: Open, Length: 7328, dtype: float64

# %%
plt.plot(df.Close);
plt.xlabel('Volume');
plt.ylabel('Close Price');

# %%
plt.plot(df.Close);
plt.xlabel('Volume');
plt.ylabel('Close');

# %%
### Scatter plot with regplot
sns.regplot(x = 'Volume',y = 'Open', data = df);
